# %%
import pandas as pd

df = pd.read_csv('data/2018-01-01-2024-05-01-Israel-Palestine-Russia-Ukraine.csv')

# %%
df
# Out:
#        event_id_cnty       event_date  year  time_precision  \
# 0           ISR39876    26 April 2024  2024               1
# 1           ISR39919    26 April 2024  2024               1
# 2           ISR39923    26 April 2024  2024               1
# 3           ISR39938    26 April 2024  2024               1
# 4           ISR39942    26 April 2024  2024               1
# ...              ...              ...   ...             ...
# 231234          UKR2  01 January 2018  2018               1
# 231235          UKR3  01 January 2018  2018               1
# 231236          UKR6  01 January 2018  2018               1
# 231237          UKR8  01 January 2018  2018               1
# 231238          UKR9  01 January 2018  2018               1
#
#              disorder_type                  event_type  \
# 0           Demonstrations                    Protests
# 1       Political violence  Violence against civilians
# 2           Demonstrations                    Protests
# ...
